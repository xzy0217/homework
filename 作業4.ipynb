# %% [markdown]
# <a href="https://colab.research.google.com/github/xzy0217/homework/blob/main/%E4%BD%9C%E6%A5%AD4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')  #取得允許

# %%
import os
os.chdir('/content/drive/MyDrive/exam/')  #切換該資料夾目錄

# %%
root_path=os.getcwd()
file_path=root_path+'/population.csv'  #取得目錄路徑

# %%
f=open(file_path,"r")
text=f.read()
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
print(text)

# %%
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/exam')  # Colab 換路徑使用

import csv
csvfile = open('population.csv')     # 開啟 CSV 檔案
raw_data = csv.reader(csvfile)     # 讀取 CSV 檔案
data = list(raw_data)              # 轉換成二維串列
print(data)
'''
[['name', 'id', 'color', 'price'],
 ['apple', '1', 'red', '10'],
 ['orange', '2', 'orange', '15'],
 ['grap', '3', 'purple', '20'],
 ['watermelon', '4', 'green', '30']]
'''
# Out:
# [['year', 'pop'], ['1950', '2.53'], ['1951', '2.57'], ['1952', '2.62'], ['1953', '2.67'], ['1954', '2.71'], ['1955', '2.76'], ['1956', '2.81'], ['1957', '2.86'], ['1958', '2.92'], ['1959', '2.97'], ['1960', '3.03'], ['1961', '3.08'], ['1962', '3.14'], ['1963', '3.2'], ['1964', '3.26'], ['1965', '3.33'], ['1966', '3.4'], ['1967', '3.47'], ['1968', '3.54'], ['1969', '3.62'], ['1970', '3.69'], ['1971', '3.77'], ['1972', '3.84'], ['1973', '3.92'], ['1974', '4.0'], ['1975', '4.07'], ['1976', '4.15'], ['1977', '4.22'], ['1978', '4.3'], ['1979', '4.37'], ['1980', '4.45'], ['1981', '4.53'], ['1982', '4.61'], ['1983', '4.69'], ['1984', '4.78'], ['1985', '4.86'], ['1986', '4.95'], ['1987', '5.05'], ['1988', '5.14'], ['1989', '5.23'], ['1990', '5.32'], ['1991', '5.41'], ['1992', '5.49'], ['1993', '5.58'], ['1994', '5.66'], ['1995', '5.74'], ['1996', '5.82'], ['1997', '5.9'], ['1998', '5.98'], ['1999', '6.05'], ['2000', '6.13'], ['2001', '6.2'], ['2002', '6.28'], ['2003', '6.36'], ['2004', '6.44
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/exam')  # Colab 換路徑使用

import openpyxl
wb = openpyxl.load_workbook('test.xlsx', data_only=True)  # 設定 data_only=True 只讀取計算後的數值

s1 = wb['csv']

def get_values(sheet):
    arr = []                      # 第一層串列
    for row in sheet:
        arr2 = []                 # 第二層串列
        for column in row:
            arr2.append(column.value)  # 寫入內容
        arr.append(arr2)
    return arr

print(get_values(s1))       # 印出工作表 1 所有內容
# Out:
# [['year', 'pop'], ['1950', '2.53'], ['1951', '2.57'], ['1952', '2.62'], ['1953', '2.67'], ['1954', '2.71'], ['1955', '2.76'], ['1956', '2.81'], ['1957', '2.86'], ['1958', '2.92'], ['1959', '2.97'], ['1960', '3.03'], ['1961', '3.08'], ['1962', '3.14'], ['1963', '3.2'], ['1964', '3.26'], ['1965', '3.33'], ['1966', '3.4'], ['1967', '3.47'], ['1968', '3.54'], ['1969', '3.62'], ['1970', '3.69'], ['1971', '3.77'], ['1972', '3.84'], ['1973', '3.92'], ['1974', '4.0'], ['1975', '4.07'], ['1976', '4.15'], ['1977', '4.22'], ['1978', '4.3'], ['1979', '4.37'], ['1980', '4.45'], ['1981', '4.53'], ['1982', '4.61'], ['1983', '4.69'], ['1984', '4.78'], ['1985', '4.86'], ['1986', '4.95'], ['1987', '5.05'], ['1988', '5.14'], ['1989', '5.23'], ['1990', '5.32'], ['1991', '5.41'], ['1992', '5.49'], ['1993', '5.58'], ['1994', '5.66'], ['1995', '5.74'], ['1996', '5.82'], ['1997', '5.9'], ['1998', '5.98'], ['1999', '6.05'], ['2000', '6.13'], ['2001', '6.2'], ['2002', '6.28'], ['2003', '6.36'], ['2004', '6.44
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('population.csv')
data.to_excel('test.xlsx', index=False)
excel_data = pd.read_excel('test.xlsx')
plt.plot(excel_data['pop'],excel_data['year'])
plt.xlabel('pop')
plt.ylabel('year')
plt.show()

# %%
data = pd.read_csv('population.csv')
data.to_excel('test.xlsx', index=False)
excel_data = pd.read_excel('test.xlsx')
plt.plot(excel_data['pop'],excel_data['year'])
plt.xlabel('pop')
plt.pie(excel_data['pop'],radius=4, labels=excel_data['year'])
plt.show()
